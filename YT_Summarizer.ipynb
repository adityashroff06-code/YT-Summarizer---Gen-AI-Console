# %% [markdown]
# # GenAI Video Briefing Console
#
# This notebook uses the same maintained pipeline as the CLI and local web app. Start Jupyter from the repository root. See [setup](docs/setup.md) and [usage](docs/usage.md) before making requests. Audio and transcripts are sent to OpenAI and consume API credit.

# %% [markdown]
# ## 1. Install the application dependencies
#
# Install FFmpeg separately and ensure both `ffmpeg` and `ffprobe` are on PATH. Restart the kernel after installation if necessary.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## 2. Configure your private API key
#
# Copy `.env.example` to `.env` and set your own key, or use the hidden prompt below. Do not paste credentials into notebook source cells or save them in output.

# %%
import os
from getpass import getpass
from dotenv import load_dotenv

load_dotenv()
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API key: ")

# %% [markdown]
# ## 3. Create a briefing
#
# Replace the empty value with a completed public YouTube video containing speech. The default limit is 30 minutes, with a separate 24 MB file bound. An empty URL skips the paid call when using Run All.

# %%
from summarizer import summarize_youtube_video

video_url = ""
if video_url.strip():
    summary = summarize_youtube_video(video_url, language="")
    print(summary)
else:
    print("Set video_url to summarize a video.")

# %% [markdown]
# ## 4. Optional local interface
#
# Launching creates a local server; no public sharing link is enabled. In hosted notebook environments, use a supported local runtime or the CLI rather than exposing your API key through a public demo.

# %%
from app import create_app

demo = create_app()
# Run the next line explicitly when you want to launch the interface.
# demo.queue(default_concurrency_limit=1, max_size=8).launch(server_name="127.0.0.1", share=False)

# %% [markdown]
# ## Next steps
#
# Review generated claims against the source video. Clear all notebook outputs before committing. The [retrieval notebook](MIT%20COCOMELON.ipynb) explores a separate local semantic-search experiment; retrieval is not part of this briefing pipeline.
